# %%
import pickle
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

# %%
data = pd.read_csv("../data/teach_data/data.csv",sep=',',error_bad_lines=True, encoding="utf-8")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-105-65b6d801e296> in <module>
# ----> 1 data = pd.read_csv("../data/teach_data/data.csv", sep=',',error_bad_lines=True, encoding="utf-8",parser='python')
#
# TypeError: parser_f() got an unexpected keyword argument 'parser'

# %%
data.columns
# Out:
# Index(['69561', 'C', '0', '4', '36102', '0.1',
#        'Windows Vista to XP Downgrading/Reformat?',
#        '<a href='http://paparadit.blogspot.com/2007/06/installing-sata-hard-drive-with-windows.html' target='_blank' rel='nofollow noopener noreferrer'>http://paparadit.blogspot.com/2007/06/installing-sata-hard-drive-with-windows.html</a>',
#        '0.2', '136', '0.3', '1', '180', 'IN', '1234889592', '1306387514',
#        '865612499', '4.1'],
#       dtype='object')

# %%
data.shape
# Out:
# (756854, 18)

# %%
data.head()
# Out:
#     69561  C  0  4  36102 0.1  Windows Vista to XP Downgrading/Reformat?  \
# 0  587308  C  0  4  17183   0  Windows Vista to XP Downgrading/Reformat?
# 1  587682  C  0  4   8981   0  Windows Vista to XP Downgrading/Reformat?
# 2  614161  C  0  4   6930   0  Windows Vista to XP Downgrading/Reformat?
# 3       4  Q  0  4      0   1  Windows Vista to XP Downgrading/Reformat?
# 4      13  A  0  4      4   0  Windows Vista to XP Downgrading/Reformat?
#
#   <a href='http://paparadit.blogspot.com/2007/06/installing-sata-hard-drive-with-windows.html' target='_blank' rel='nofollow noopener noreferrer'>http://paparadit.blogspot.com/2007/06/installing-sata-hard-drive-with-windows.html</a>  \
# 0  but my does not have where to off the SATA. wh...
# 1  windows 7 (very similar to windows vista) won'...
# 2  any body in this forum having problem of doung...
# 3  Hello,\r\\n<br>I bought a new laptop with Wind...
# 4  I don't think that they're lying on that one.....
#
# ...

# %%
data.columns = ["id","question_answer_or_comment" , "is_best_answer","topic_id",
"parent_id","votes","titre","message","member", "category", "state", 
 "is_solved", "num_answers", "country", "date","last_answer_date", 
 "auteur_crc", "visits"]

# %%
data.head()
# Out:
#        id question_answer_or_comment is_best_answer topic_id parent_id votes  \
# 0  587308                          C              0        4     17183     0
# 1  587682                          C              0        4      8981     0
# 2  614161                          C              0        4      6930     0
# 3       4                          Q              0        4         0     1
# 4      13                          A              0        4         4     0
#
#                                        titre  \
# 0  Windows Vista to XP Downgrading/Reformat?
# 1  Windows Vista to XP Downgrading/Reformat?
# 2  Windows Vista to XP Downgrading/Reformat?
# 3  Windows Vista to XP Downgrading/Reformat?
# 4  Windows Vista to XP Downgrading/Reformat?
#
#                                              message member category state  \
# 0  but my does not have where to off the SATA. wh...      0      136     0
# 1  windows 7 (very similar to windows vista) won'...      0      136     0
# ...

# %%
for i in data['is_best_answer'].unique():
    print(i)
# Out:
# 0
# 1
# 0
# 1
# nan
# 140
#  Order:=xlAscending
# 5
#  and insert the formula as if you selected only the first cell at the top. Excel will know to apply the correct formulas to all the other cells in the range (assuming the range is a column).
#  cfind As Range\
#  0)\
#  &quot;B&quot;).End(xlUp).Offset(1
#  if you cant tell just hit the y key and then enter.
# 11
# 156
#  Temp\
#  2))\
# 25
# 27
#  eg; D:\\Steam\\steamapps\\common\\ there should be a folder called\"call of duty modern warfare 2\"
# 3.0
# 2.0
# 7.0
# 25.0
# 126
# 3
# 7
#  and click on New Task and then click on Browse
#  when I get to the 'settings' screen and press alt 4
#  un menu apparaîtra. Sélectionnez l'option numéro 2
#  cliquez sur
#  select all and delete
# 154
# 132
# 2
# 182
#  Chipset & Southbridge and I'll be happy to give you a link to download your missing drivers.
# 101
# \
#  Visa
#  etc)
#  while the code looks only at column G for any changes.
#  1).PasteSpecial\
#  z As Integer\
#  \"A\")\
# ...
